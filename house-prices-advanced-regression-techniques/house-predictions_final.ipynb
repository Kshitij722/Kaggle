# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/house-prices-advanced-regression-techniques/sample_submission.csv
# /kaggle/input/house-prices-advanced-regression-techniques/data_description.txt
# /kaggle/input/house-prices-advanced-regression-techniques/train.csv
# /kaggle/input/house-prices-advanced-regression-techniques/test.csv

# %%
import pandas as pd

dataset_train = pd.read_csv("/kaggle/input/house-prices-advanced-regression-techniques/train.csv")
dataset_train
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
dataset_test = pd.read_csv("/kaggle/input/house-prices-advanced-regression-techniques/test.csv")
dataset_test
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1     1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2     1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3     1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4     1465         120       RL         43.0     5005   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
# ...

# %%
dataset_train["SalePrice"].mean()

# %%
dataset_test["SalePrice"] = pd.Series([dataset_train["SalePrice"].mean()]*len(dataset_train))
dataset_test

# %%
dataset_test[["Id","SalePrice"]].to_csv("average_prediction.csv",index=False)

# %%
from copy import deepcopy
dataset_train_sub = deepcopy(dataset_train[["MSSubClass","LotFrontage","SalePrice"]])
dataset_train_sub
# Out:
#       MSSubClass  LotFrontage  SalePrice
# 0             60         65.0     208500
# 1             20         80.0     181500
# 2             60         68.0     223500
# 3             70         60.0     140000
# 4             60         84.0     250000
# ...          ...          ...        ...
# 1455          60         62.0     175000
# 1456          20         85.0     210000
# 1457          70         66.0     266500
# 1458          20         68.0     142125
# 1459          20         75.0     147500
#
# [1460 rows x 3 columns]

# %%
dataset_train_sub = dataset_train_sub.fillna(dataset_train_sub.mean())

# %%
x_train = dataset_train_sub.iloc[:,:-1].to_numpy()
y_train = dataset_train_sub.iloc[:,-1].to_numpy()

# %% [raw]
# from sklearn.linear_model import LinearRegression
# lr = LinearRegression()
# lr.fit(x_train,y_train)
# lr

# %%
lr.coef_
# Out:
# array([  75.96942776, 1260.11397803])

# %%
lr.intercept_
# Out:
# 88327.8118861935

# %%
dataset_train_sub["LinearPrediction"] = lr.predict(x_train)
dataset_train_sub
# Out:
#       MSSubClass  LotFrontage  SalePrice  Linear prediction  LinearPrediction
# 0             60         65.0     208500      174793.386124     174793.386124
# 1             20         80.0     181500      190656.318684     190656.318684
# 2             60         68.0     223500      178573.728058     178573.728058
# 3             70         60.0     140000      169252.510511     169252.510511
# 4             60         84.0     250000      198735.551706     198735.551706
# ...          ...          ...        ...                ...               ...
# 1455          60         62.0     175000      171013.044190     171013.044190
# 1456          20         85.0     210000      196956.888574     196956.888574
# 1457          70         66.0     266500      176813.194379     176813.194379
# 1458          20         68.0     142125      175534.950948     175534.950948
# 1459          20         75.0     147500      184355.748794     184355.748794
#
# [1460 rows x 5 columns]

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(dataset_train_sub["SalePrice"],dataset_train_sub["LinearPrediction"])
# Out:
# 54381.25047406032

# %%
dataset_test_sub = deepcopy(dataset_test[["MSSubClass","LotFrontage"]])
dataset_test_sub
# Out:
#       MSSubClass  LotFrontage
# 0             20         80.0
# 1             20         81.0
# 2             60         74.0
# 3             60         78.0
# 4            120         43.0
# ...          ...          ...
# 1454         160         21.0
# 1455         160         21.0
# 1456          20        160.0
# 1457          85         62.0
# 1458          60         74.0
#
# [1459 rows x 2 columns]

# %%
dataset_test_sub = dataset_test_sub.fillna(dataset_test_sub.mean())

# %%
x_test = dataset_test_sub.to_numpy()
x_test
# Out:
# array([[ 20.,  80.],
#        [ 20.,  81.],
#        [ 60.,  74.],
#        ...,
#        [ 20., 160.],
#        [ 85.,  62.],
#        [ 60.,  74.]])

# %%
dataset_test["SalePrice"] = lr.predict(x_test)
dataset_test
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1     1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2     1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3     1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4     1465         120       RL         43.0     5005   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
# ...

# %%
dataset_test[["Id","SalePrice"]].to_csv("linear_prediction.csv",index=False)
